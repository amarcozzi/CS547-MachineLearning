# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('old_models/results.npy')

# %%
plt.plot(data[1, :])
plt.show()

# %%
plt.plot(data[2, :])
plt.show()

# %%
plt.plot(data[4, :])
plt.show()
